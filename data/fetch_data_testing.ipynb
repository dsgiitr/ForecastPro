# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
import tensorflow as tf
import os
import pickle
import json
from tensorflow.keras.models import model_from_json
from lstnet_util import GetArguments, LSTNetInit
from lstnet_model import PreSkipTrans, PostSkipTrans, PreARTrans, PostARTrans, LSTNetModel, ModelCompile
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35468/1140646593.py in <module>
#       9 import json
#      10 from tensorflow.keras.models import model_from_json
# ---> 11 from lstnet_util import GetArguments, LSTNetInit
#      12 from lstnet_model import PreSkipTrans, PostSkipTrans, PreARTrans, PostARTrans, LSTNetModel, ModelCompile
#
# ModuleNotFoundError: No module named 'lstnet_util'

# %%
import yfinance as yf
amz_ticker = "^AMZ"
amz_data = yf.download(amz_ticker, period="4000d")
df=amz_data['Open']
dpz_ticker="DPZ"
dpz_data=yf.download(dpz_ticker, period="4000d")
df=pd.concat([df,dpz_data['Open']], axis=1)
nflx_ticker="NFLX"
nflx_data=yf.download(nflx_ticker, period="4000d")
df=pd.concat([df,nflx_data['Open']], axis=1)
googl_ticker="GOOGL"
googl_data=yf.download(googl_ticker, period="4000d")
df=pd.concat([df,googl_data['Open']], axis=1)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   Open        Open        Open        Open
# Date
# 2007-08-08  305.980011   17.980000    2.490000   12.996496
# 2007-08-09  310.059998   16.500000    2.432857   13.033033
# 2007-08-10  299.750000   15.570000    2.557143   12.767267
# 2007-08-13  297.959991   17.549999    2.571429   13.001502
# 2007-08-14  303.440002   17.740000    2.475714   12.905906
# ...                ...         ...         ...         ...
# 2023-06-22  226.529999  322.000000  422.929993  120.000000
# 2023-06-23  224.500000  320.000000  418.589996  121.379997
# 2023-06-26  222.500000  315.000000  422.440002  120.760002
# 2023-06-27  224.470001  320.000000  417.390015  117.080002
# ...

# %%
df.columns=['AMZ','DPZ','NFLX','GOOGL']

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
np.array(df)
# Out:
# array([[305.98001099,  17.97999954,   2.49000001,  12.9964962 ],
#        [310.05999756,  16.5       ,   2.43285704,  13.03303337],
#        [299.75      ,  15.56999969,   2.55714297,  12.76726723],
#        ...,
#        [222.5       , 315.        , 422.44000244, 120.76000214],
#        [224.47000122, 320.        , 417.39001465, 117.08000183],
#        [224.86000061, 324.63000488, 423.1000061 , 117.08999634]])
